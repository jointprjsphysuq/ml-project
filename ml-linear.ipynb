# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sc_df = pd.read_csv('superconductors.csv')
sc_df.drop('Unnamed: 0', axis = 1, inplace = True)
sc_df
# Out:
#        number_of_elements  mean_atomic_mass    mean_fie  mean_atomic_radius  \
# 0                       4         88.944468  775.425000          160.250000
# 1                       5         92.729214  766.440000          161.200000
# 2                       4         88.944468  775.425000          160.250000
# 3                       4         88.944468  775.425000          160.250000
# 4                       4         88.944468  775.425000          160.250000
# ...                   ...               ...         ...                 ...
# 21258                   4        106.957877  661.775000          176.500000
# 21259                   5         92.266740  747.780000          159.200000
# 21260                   2         99.663190  733.550000          183.500000
# 21261                   2         99.663190  733.550000          183.500000
# 21262                   3         87.468333  856.166667          127.333333
#
# ...

# %%
sc_df.describe()
# Out:
#        number_of_elements  mean_atomic_mass      mean_fie  mean_atomic_radius  \
# count        21263.000000      21263.000000  21263.000000        21263.000000
# mean             4.115224         87.557631    769.614748          157.983101
# std              1.439295         29.676497     87.488694           20.147288
# min              1.000000          6.941000    375.500000           48.000000
# 25%              3.000000         72.458076    723.740000          149.333333
# 50%              4.000000         84.922750    764.900000          160.250000
# 75%              5.000000        100.404410    796.320000          169.857143
# max              9.000000        208.980400   1313.100000          298.000000
#
#        mean_Density  mean_ElectronAffinity  mean_FusionHeat  \
# count  21263.000000           21263.000000     21263.000000
# mean    6111.465214              76.879751        14.296113
# std     2846.785185              27.701890        11.300188
# ...

# %%
correlations = sc_df.corr()
f, ax = plt.subplots(figsize= (11, 9))
cmap = sns.diverging_palette(550, 20, as_cmap = True)
sns.heatmap(correlations, cmap = cmap, linewidths = 0.5, center = 0, annot = True)
# Out:
# <AxesSubplot:>
